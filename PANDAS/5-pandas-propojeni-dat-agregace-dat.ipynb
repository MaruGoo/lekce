# %% [markdown]
# # `pandas`: Propojení dat
# Odkaz na lekci: https://kodim.cz/kurzy/python-data-1/python-pro-data-1/agregace-a-spojovani/propojeni-dat

# %%
import pandas

# %% [markdown]
# ### Načtení dat
#
# Data, se kterými budeme pracovat, si můžeš stáhnout zde:
# * [studenti.csv](https://kodim.cz/cms/assets/kurzy/python-data-1/python-pro-data-1/agregace-a-spojovani/studenti.csv)
# * [predsedajici.csv](https://kodim.cz/cms/assets/kurzy/python-data-1/python-pro-data-1/agregace-a-spojovani/predsedajici.csv)

# %%
studenti = pandas.read_csv("studenti.csv")
studenti.head()
# studenti.info()
# Out:
#    cisloStudenta             jmeno
# 0              1    Jana Zbořilová
# 1              2      Lukáš Jurčík
# 2              3       Pavel Horák
# 3              4     Pavel Kysilka
# 4              5  Kateřina Novotná

# %%
predsedajici = pandas.read_csv("predsedajici.csv")
predsedajici["den"] = predsedajici["den"].str.strip()
predsedajici.head()
# predsedajici.info()
# Out:
#        datum             jmeno den
# 0  20.5.2019  Marie Zuzaňáková  po
# 1  21.5.2019  Marie Zuzaňáková  út
# 2  22.5.2019     Petr Ortinský  st
# 3  23.5.2019     Petr Ortinský  čt
# 4  24.5.2019   Alena Pniáčková  pá

# %% [markdown]
# Také budeme potřebovat tabulku `maturita.csv`, kterou jsme si vytvořili minulou lekci. Pokud jí nemáš po ruce, stáhni si jí zde: [maturita.csv](https://raw.githubusercontent.com/lutydlitatova/python-jaro-2023/main/notebook/maturita.csv)

# %%
maturita = pandas.read_csv("maturita.csv")
maturita.head()
# maturita.info()
# Out:
#    cisloStudenta           predmet  znamka den místnost
# 0              2           Dějepis     3.0  pá     u202
# 1              3        Matematika     2.0  út     u202
# 2              2  Společenské vědy     2.0  pá     u202
# 3              4          Biologie     1.0  pá     u202
# 4              5           Dějepis     1.0  po     u202

# %% [markdown]
# ### Propojení dat pomocí `merge`
# Jak `pandas` pozná, podle kterých sloupců data propojit? Jak můžeme sloupce, podle kterých chceme data propojit, specifikovat?

# %%
maturita_se_studenty = pandas.merge(maturita, studenti)
maturita_se_studenty.shape
# Out:
# (36, 6)

# %% [markdown]
# Propojení dat o maturitě s daty o předsedajících se nepovede. Proč? Na základě kterého sloupce nebo kterých sloupců chceme data propojit? Budeme také muset vyřešit záhadu poztrácených dat.

# %%
maturita_s_predsedajicimi = pandas.merge(maturita_se_studenty, predsedajici, on=['den'])
# maturita_s_predsedajicimi = pandas.merge(maturita_se_studenty, predsedajici, on=['den'], how="left") kdyby nebyla u predsedajicích odstranena mezera
maturita_s_predsedajicimi.head()
# Out:
#    cisloStudenta           predmet  znamka den místnost          jmeno_x  \
# 0              2           Dějepis     3.0  pá     u202     Lukáš Jurčík
# 1              2  Společenské vědy     2.0  pá     u202     Lukáš Jurčík
# 2              4          Biologie     1.0  pá     u202    Pavel Kysilka
# 3              4       Informatika     1.0  pá     u302    Pavel Kysilka
# 4             15            Chemie     3.0  pá     u203  Monika Dudysová
#
#        datum          jmeno_y
# 0  24.5.2019  Alena Pniáčková
# 1  24.5.2019  Alena Pniáčková
# 2  24.5.2019  Alena Pniáčková
# 3  24.5.2019  Alena Pniáčková
# 4  24.5.2019  Alena Pniáčková

# %% [markdown]
# # `pandas`: Agregace dat
# Odkaz na lekci: https://kodim.cz/kurzy/python-data-1/python-pro-data-1/agregace-a-spojovani/agregace

# %%
maturita_s_predsedajicimi.groupby("predmet")

# %%
maturita_s_predsedajicimi.groupby("predmet")["znamka"]

# %%
maturita_s_predsedajicimi.groupby("predmet")["znamka"].mean()
# Out:
# predmet
# Biologie            2.750000
# Chemie              3.800000
# Dějepis             3.200000
# Fyzika              2.800000
# Informatika         2.600000
# Matematika          2.714286
# Společenské vědy    2.666667
# Zeměpis             2.000000
# Name: znamka, dtype: float64

# %%
maturita_s_predsedajicimi.groupby("predmet")["znamka"].max()
# Out:
# predmet
# Biologie            4.0
# Chemie              5.0
# Dějepis             5.0
# Fyzika              4.0
# Informatika         4.0
# Matematika          5.0
# Společenské vědy    3.0
# Zeměpis             3.0
# Name: znamka, dtype: float64

# %% [markdown]
# Řazení:

# %%
staty = pandas.read_json("staty.json")
staty = staty.set_index("name")
staty["population_density"] = staty["population"] / staty["area"]
staty = staty.sort_values("population_density", ascending=False)
staty
# Out:
#                                              alpha2Code alpha3Code  \
# name
# Macao                                                MO        MAC
# Monaco                                               MC        MCO
# Singapore                                            SG        SGP
# Hong Kong                                            HK        HKG
# Gibraltar                                            GI        GIB
# ...                                                 ...        ...
# Palestine, State of                                  PS        PSE
# Réunion                                              RE        REU
# Saint Helena, Ascension and Tristan da Cunha         SH        SHN
# South Georgia and the South Sandwich Islands         GS        SGS
# Svalbard and Jan Mayen                               SJ        SJM
#
#                                                         capital    region  \
# name
# Macao                                                                Asia
# Monaco                                                   Monaco    Europe
# Singapore                                             Singapore      Asia
# Hong Kong                                      City of Victoria      Asia
# Gibraltar                                             Gibraltar    Europe
# ...                                                         ...       ...
# Palestine, State of                                    Ramallah      Asia
# Réunion                                             Saint-Denis    Africa
# Saint Helena, Ascension and Tristan da Cunha          Jamestown    Africa
# South Georgia and the South Sandwich Islands  King Edward Point  Americas
# Svalbard and Jan Mayen                             Longyearbyen    Europe
#
#                                                        subregion  population  \
# name
# Macao                                               Eastern Asia      649100
# Monaco                                            Western Europe       38400
# Singapore                                     South-Eastern Asia     5535000
# Hong Kong                                           Eastern Asia     7324300
# Gibraltar                                        Southern Europe       33140
# ...                                                          ...         ...
# Palestine, State of                                 Western Asia     4682467
# Réunion                                           Eastern Africa      840974
# Saint Helena, Ascension and Tristan da Cunha      Western Africa        4255
# South Georgia and the South Sandwich Islands       South America          30
# Svalbard and Jan Mayen                           Northern Europe        2562
#
#                                                  area  gini  \
# name
# Macao                                           30.00   NaN
# Monaco                                           2.02   NaN
# Singapore                                      710.00  48.1
# Hong Kong                                     1104.00  53.3
# Gibraltar                                        6.00   NaN
# ...                                               ...   ...
# Palestine, State of                               NaN  35.5
# Réunion                                           NaN   NaN
# Saint Helena, Ascension and Tristan da Cunha      NaN   NaN
# South Georgia and the South Sandwich Islands      NaN   NaN
# Svalbard and Jan Mayen                            NaN   NaN
#
#                                               population_density
# name
# Macao                                               21636.666667
# Monaco                                              19009.900990
# Singapore                                            7795.774648
# Hong Kong                                            6634.329710
# Gibraltar                                            5523.333333
# ...                                                          ...
# Palestine, State of                                          NaN
# Réunion                                                      NaN
# Saint Helena, Ascension and Tristan da Cunha                 NaN
# South Georgia and the South Sandwich Islands                 NaN
# Svalbard and Jan Mayen                                       NaN
#
# [250 rows x 9 columns]

# %% [markdown]
# `size` vs `count`
# * https://pandas.pydata.org/docs/reference/api/pandas.core.groupby.GroupBy.size.html
# * https://pandas.pydata.org/docs/reference/api/pandas.core.groupby.GroupBy.count.html

# %%
maturita_s_predsedajicimi.groupby("predmet").count()
# Out:
#                   cisloStudenta  znamka  den  místnost  jmeno_x  datum  \
# predmet
# Biologie                      4       4    4         4        4      4
# Chemie                        5       5    5         5        5      5
# Dějepis                       5       5    5         5        5      5
# Fyzika                        5       5    5         5        5      5
# Informatika                   5       5    5         5        5      5
# Matematika                    7       7    7         7        7      7
# Společenské vědy              3       3    3         3        3      3
# Zeměpis                       2       2    2         2        2      2
#
#                   jmeno_y
# predmet
# Biologie                4
# Chemie                  5
# Dějepis                 5
# Fyzika                  5
# Informatika             5
# Matematika              7
# Společenské vědy        3
# Zeměpis                 2

# %%
maturita_s_predsedajicimi.groupby("predmet").size()
# Out:
# predmet
# Biologie            4
# Chemie              5
# Dějepis             5
# Fyzika              5
# Informatika         5
# Matematika          7
# Společenské vědy    3
# Zeměpis             2
# dtype: int64
