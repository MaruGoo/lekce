# %%
import pandas

# %%
platy = pandas.read_csv("platy_2021_02.csv")

# %%
platy["plat"].plot(kind='hist', bins=[30000, 35000, 40000, 45000, 50000, 55000, 60000], grid=True, y="Počet zaměstnanců", x="Plat")
# Out:
# <Axes: ylabel='Frequency'>

# %%
platy.hist("plat")
# Out:
# array([[<Axes: title={'center': 'plat'}>]], dtype=object)
